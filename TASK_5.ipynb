# %% [markdown]
# <a href="https://colab.research.google.com/github/ayoni02/zummit-paths/blob/main/TASK_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('kyphosis.csv')

# %%
df.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
sns.set_style('darkgrid')
sns.pairplot(df,hue='Kyphosis',diag_kind='hist')

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Kyphosis',axis=1)
y = df['Kyphosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rpred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rpred))
print(classification_report(y_test,rpred))
# Out:
# [[19  0]
#  [ 5  1]]
#               precision    recall  f1-score   support
#
#       absent       0.79      1.00      0.88        19
#      present       1.00      0.17      0.29         6
#
#     accuracy                           0.80        25
#    macro avg       0.90      0.58      0.58        25
# weighted avg       0.84      0.80      0.74        25
